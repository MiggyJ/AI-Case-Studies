# %% [markdown]
# # Case Study 1
#
# Scrape the data from different regions up to the Barangay level. The output should be in CSV format. Submit a link to your folder - folder name should be your group.
#
# Once done, schedule a zoom meeting with me to discuss how you came up with the solution and explain how you extracted the data. I might randomly ask someone from your group to explain the source code.
#
# Site: [PhilAtlas](https://philatlas.com/island-groups.html)
#
# Outputs:
# - Island Group, Region
# - Region, Province Name, Type, Population (2020), Population (2015), Annual Population Growth Rate (2015 - 2020), Area (2013 in km2), Density (2020 per km2), City Count, Municipality Count, Brgy Count
# - Province, Municipality name, Type, Population (2020), Population (2015), Annual Population Growth Rate (2015 - 2020), Area (2013 in km2), Density (2020 per km2), Brgy Count
# - Municipality Name, Barangay Name, Population Percentage (2020), Population (2020), Population (2015), Change (2015 - 2020), Annual Population Growth Rate (2015 - 2020), Postal Code, Coastal/Landlocked, Marine Waterbodies, Coordinates, Estimated Elevation above sea level
#
#
# -----
# ## PROBLEMS
# - Missing Region in Island Groups:
#     - Bicol Region
# - Missing Values:
#     - lumayang(postal code order)
#     - loboc-lapuz(elevation)

# %%
# IMPORTS
import grequests
import requests
from bs4 import BeautifulSoup
import pandas as pd
import warnings
warnings.simplefilter("ignore", category=UserWarning)

# %%
#* BASE URL
base_url = 'https://www.philatlas.com/'

#* Outputs
output1 = []
output2 = []
output3 = []
output4 = []

#* Links
region_links = []
municipality_links = []
barangay_links = []

# %%
#* HEADERS FOR OUTPUT 2
headers2 = [
        'Region',
        'Province',
        'Type',
        'Population (2020)',
        'Population (2015)',
        'Annual Population Growth Rate (2015 - 2020)',
        'Area (2013 in km2)',
        'Density (2020 per km2)',
        'City Count',
        'Municipality Count',
        'Barangay Count'
]

#* HEADERS FOR OUTPUT 3
headers3 = [
    'Province',
    'Municipality name',
    'Type',
    'Population (2020)',
    'Population (2015)',
    'Annual Population Growth Rate (2015 - 2020)',
    'Area (2013 in km2)',
    'Density (2020 per km2)',
    'Brgy Count',
]

#* HEADERS FOR OUTPUT 4
headers4 = [
    'Municipality Name',
    'Barangay Name',
    'Population Percentage (2020)',
    'Population (2020)',
    'Population (2015)',
    'Change (2015 - 2020)',
    'Annual Population Growth Rate (2015 - 2020)',
    'Postal Code',
    'Coastal/Landlocked',
    'Marine Waterbodies',
    'Coordinates',
    'Estimated Elevation above sea level'
]

#* MUNICIPALITIES IN NCR
ncr_municipalities = []

#* PROVINCES WITH NO MUNICIPALITIES
no_municipalities = []

#* FAILED LINKS AND DETAILS
failed_links = []
exception_details = []

# %% [markdown]
# # OUTPUT 1

# %%
def getRegionByIslandGroups():
    # RESET OUTPUT 1 AND REGION LINKS
    del output1[:]
    del region_links[:]

    # GET SITE CONTENT
    url = base_url + '/island-groups.html'
    page = requests.get(url).content
    site = BeautifulSoup(page, 'html.parser')

    # SELECT TABLE AND FETCH ROWS
    section = site.select_one('#listIslGrps')
    table = section.select_one('.generic-table')
    body = table.find('tbody').contents

    # FOR DATA IN EACH ROW
    for el in body:
        island_group = el.find('th').find('a').text
        region_list = el.find('ul')

        # FOR REGION IN DATA
        for index, data in enumerate(region_list):
            temp = [island_group, data.find('a').text]

            # GET BICOL REGION
            if index == 5 and island_group == 'Luzon':
                output1.append([island_group, 'V - Bicol Region'])
            output1.append(temp)

            # NCR HAS NO PROVINCE, SO ADD TO MUNICIPALITY LINK
            if data.find('a').text == 'NCR – National Capital Region':
                municipality_links.append(data.find('a').attrs['href'])
                
                # ADD BICOL REGION LINK BEFORE NCR
                region_links.append('luzon/r05.html')
            
            # ADD TO REGION LINKS
            region_links.append(data.find('a').attrs['href'])

    # PUT OUTPUT1 IN DATAFRAME AND CONVERT TO CSV
    df = pd.DataFrame(output1, columns=['Island Group', 'Region'])
    df.to_csv('../output/output_1.csv', index=False, mode='wb')

# %%
getRegionByIslandGroups()

pd.DataFrame(output1, columns=['Island Group', 'Region'])
# Out:
#    Island Group                                             Region
# 0         Luzon                                  I – Ilocos Region
# 1         Luzon                                II – Cagayan Valley
# 2         Luzon                                III – Central Luzon
# 3         Luzon                                  IV‑A – CALABARZON
# 4         Luzon                                    MIMAROPA Region
# 5         Luzon                                   V - Bicol Region
# 6         Luzon                      NCR – National Capital Region
# 7         Luzon             CAR – Cordillera Administrative Region
# 8       Visayas                               VI – Western Visayas
# 9       Visayas                              VII – Central Visayas
# 10      Visayas                             VIII – Eastern Visayas
# 11     Mindanao                           IX – Zamboanga Peninsula
# 12     Mindanao                              X – Northern Mindanao
# 13     Mindanao                                  XI – Davao Region
# 14     Mindanao                                 XII – SOCCSKSARGEN
# 15     Mindanao                                      XIII – Caraga
# 16     Mindanao  BARMM – Bangsamoro Autonomous Region in Muslim...

# %% [markdown]
# # OUTPUT 2

# %%
def getProvinceByRegion():
    # RESET OUTPUT2 AND MUNICIPALITY LINKS
    del output2[:]
    # DO NOT REMOVE NCR MUNICIPALITIES
    del municipality_links[1:]

    # COLLECT LINKS AND REQUEST ASYNC
    reqs = (grequests.get(base_url + link) for link in region_links)
    resp=grequests.map(reqs, grequests.Pool(10), size=10)
    step = 0

    # FOR EACH RESPONSE
    for index, r in enumerate(resp):

        # GET SITE CONTENT
        site = BeautifulSoup(r.content, 'html.parser')
        
        # GET TABLE AND ITS ROWS
        table = site.select_one('#lguTable')
        body = table.find('tbody').contents

        # FOR DATA IN ROW
        for el in body:
            # GET REGION BY ORDER OF REGION LINK
            region = output1[index][1]

            # NCR HAS NO PROVINCES SO ADD DATA TO NCR MUNICIPALITIES
            if region == 'NCR – National Capital Region':
                ncr_municipalities.append(el.find('th').find('a').text)
                
            else:
                # PUT REGION NAME IN FIRST COLUMN
                temp = [region]
                
                # FOR EACH TD
                for data in el:

                    # FIND LINK OF PROVINCE
                    name =  data.find('a')

                    # IF EXISTS
                    if name:
                        
                        # IF NO CITY AND MUNICIPALITY
                        if el.select_one('td:nth-child(8)').text == '–' and el.select_one('td:nth-child(9)').text == '–':

                            # ADD TO BARANGAY LINKS
                            barangay_links.append(name.attrs['href'])

                            # ADD TO NO MUNICIPALITY
                            no_municipalities.append(name.text)
                        

                        # ADD LINK TO MUNICIPALITY LINKS
                        municipality_links.append(name.attrs['href'])

                        # ADD TO TEMPORARY HOLDER
                        temp.append(name.text)

                    else:
                        # IF DATA IS NOT AVAILABLE
                        if data.text == '–':
                            temp.append(0)
                        else:
                            temp.append(data.text)
                # INSERT TEMP TO OUTPUT 2
                output2.append(temp)


    # MAKE OUTPUT2 DATAFRAME AND CONVERT TO CSV
    df = pd.DataFrame(output2, columns=headers2)
    df.to_csv('../output/output_2.csv', index=False)

# %%
getProvinceByRegion()

# %%
no_municipalities
# Out:
# ['Angeles',
#  'Olongapo',
#  'Lucena',
#  'Puerto Princesa',
#  'Baguio',
#  'Bacolod',
#  'Iloilo City',
#  'Cebu City',
#  'Lapu-Lapu',
#  'Mandaue',
#  'Tacloban',
#  'Isabela City',
#  'Zamboanga City',
#  'Cagayan de Oro',
#  'Iligan',
#  'Davao City',
#  'Cotabato City',
#  'General Santos',
#  'Butuan']

# %%
pd.DataFrame(output2, columns=headers2)
# Out:
#                                                Region       Province  \
# 0                                   I – Ilocos Region   Ilocos Norte
# 1                                   I – Ilocos Region     Ilocos Sur
# 2                                   I – Ilocos Region       La Union
# 3                                   I – Ilocos Region     Pangasinan
# 4                                 II – Cagayan Valley        Batanes
# ..                                                ...            ...
# 95  BARMM – Bangsamoro Autonomous Region in Muslim...        Basilan
# 96  BARMM – Bangsamoro Autonomous Region in Muslim...  Lanao del Sur
# 97  BARMM – Bangsamoro Autonomous Region in Muslim...    Maguindanao
# 98  BARMM – Bangsamoro Autonomous Region in Muslim...           Sulu
# 99  BARMM – Bangsamoro Autonomous Region in Muslim...      Tawi-Tawi
#
#         Type Population (2020) Population (2015)  \
# 0   province           609,588           593,081
# 1   province           706,009           689,668
# 2   province           822,352           786,653
# 3   province         3,163,190         2,956,726
# 4   province            18,831            17,246
# ..       ...               ...               ...
# 95  province           426,207           346,579
# 96  province         1,195,518         1,045,429
# 97  province         1,342,179         1,173,933
# 98  province         1,000,108           824,731
# 99  province           440,276           390,715
#
#    Annual Population Growth Rate (2015 - 2020) Area (2013 in km2)  \
# 0                                        0.58%           3,418.75
# 1                                        0.49%           2,596.00
# 2                                        0.94%           1,499.28
# 3                                        1.43%           5,450.59
# 4                                        1.87%             203.22
# ..                                         ...                ...
# 95                                       4.45%           3,453.42
# 96                                       2.86%          15,055.51
# 97                                       2.86%           9,968.31
# 98                                       4.14%           4,547.16
# 99                                       2.55%           3,626.55
#
#    Density (2020 per km2) City Count Municipality Count Barangay Count
# 0                     178          2                 21            559
# 1                     272          2                 32            768
# 2                     548          1                 19            576
# 3                     580          4                 44          1,364
# 4                      93          0                  6             29
# ..                    ...        ...                ...            ...
# 95                    123          1                 11            210
# 96                     79          1                 39          1,159
# 97                    135          0                 36            508
# 98                    220          0                 19            410
# 99                    121          0                 11            203
#
# [100 rows x 11 columns]

# %% [markdown]
# # OUTPUT 3

# %%
def getMunicipalitiesByProvince():

    # RESET OUTPUT 3 AND BARANGAY LINKS
    del output3[:]
    # DO NOT REMOVE LINKS OF NO PROVINCE
    del barangay_links[19:]

    # COLLECT LINKS AND REQUEST ASYNC
    reqs = (grequests.get(base_url + link) for link in municipality_links)
    resp = grequests.map(reqs, grequests.Pool(10), size=10)
    
    # FOR EACH RESPONSE
    for index, r in enumerate(resp):

        # GET SITE CONTENT
        site = BeautifulSoup(r.content, 'html.parser')
        
        # GET TABLE AND ROWS
        table = site.select_one('#lguTable')
        body = table.find('tbody').contents

        # SKIP NO CITIES/MUNICIPALITIES
        if output2[index-1][1] in no_municipalities:
            continue

        for el in body:

            # FIRST MUNICIPALITY LINK IS NCR WITH NO PROVINCE
            if index == 0:
                temp = ['NCR – National Capital Region']
            else:
                # GET PROVINCE NAME BY ORDER OF MUNICIPALITY LINK
                temp = [output2[index - 1][1]]
                
            
            # FOR EACH TD
            for data in el:

                # FIND LINK OF MUNICIPALITY
                name =  data.find('a')

                # IF EXISTS
                if name:

                    # ADD TO BARANGAY LINKS
                    barangay_links.append(name.attrs['href'])
                    temp.append(name.text)
                else:

                    # ADD TO TEMP HOLDER
                    temp.append(data.text)

            # INSERT TEMP TO OUTPUT 3
            output3.append(temp)


    # MAKE OUTPUT3 DATAFRAME AND CONVERT TO CSV
    df = pd.DataFrame(output3, columns=headers3)
    df.to_csv('../output/output_3.csv', index=False)

# %%
getMunicipalitiesByProvince()

# %%
pd.DataFrame(output3, columns=headers3)
# Out:
#                            Province Municipality name          Type  \
# 0     NCR – National Capital Region          Caloocan    city (HUC)
# 1     NCR – National Capital Region         Las Piñas    city (HUC)
# 2     NCR – National Capital Region            Makati    city (HUC)
# 3     NCR – National Capital Region           Malabon    city (HUC)
# 4     NCR – National Capital Region       Mandaluyong    city (HUC)
# ...                             ...               ...           ...
# 1611                      Tawi-Tawi           Simunul  municipality
# 1612                      Tawi-Tawi         Sitangkai  municipality
# 1613                      Tawi-Tawi       South Ubian  municipality
# 1614                      Tawi-Tawi          Tandubas  municipality
# 1615                      Tawi-Tawi    Turtle Islands  municipality
#
#      Population (2020) Population (2015)  \
# 0            1,661,584         1,583,978
# 1              606,293           588,894
# 2              629,616           582,602
# 3              380,522           365,525
# 4              425,758           386,276
# ...                ...               ...
# 1611            34,245            31,223
# 1612            37,319            33,334
# 1613            29,583            25,935
# 1614            34,316            29,390
# 1615             5,683             4,727
#
#      Annual Population Growth Rate (2015 - 2020) Area (2013 in km2)  \
# 0                                          1.01%              55.80
# 1                                          0.61%              32.69
# 2                                          1.65%              21.57
# 3                                          0.85%              15.71
# 4                                          2.07%               9.29
# ...                                          ...                ...
# 1611                                       1.96%             167.25
# 1612                                       2.41%             735.46
# 1613                                       2.81%             272.04
# 1614                                       3.32%             552.05
# 1615                                       3.95%              62.50
#
#      Density (2020 per km2) Brgy Count
# 0                    29,777        188
# 1                    18,547         20
# 2                    29,189         33
# 3                    24,222         21
# 4                    45,830         27
# ...                     ...        ...
# 1611                    205         15
# 1612                     51          9
# 1613                    109         31
# 1614                     62         20
# 1615                     91          2
#
# [1616 rows x 9 columns]

# %% [markdown]
# # OUTPUT 4

# %%
def getBarangayByMunicipality():
    # RESET OUTPUT4, FAILED LINKS, AND EXCEPTION DETAILS
    del output4[:]
    del failed_links[:]
    del exception_details[:]

    # COLLECT LINKS AND REQUEST ASYNC
    reqs1 = (grequests.get(base_url + link, timeout=10) for link in barangay_links)
    resp1 = grequests.map(reqs1, grequests.Pool(10), size=10)

    # FOR EACH RESPONSE
    for index, r1 in enumerate(resp1):
        # CREATE LIST OF BARANGAY DETAILS LINK
        detail_links = []

        # CREATE 2D TEMPORARY HOLDER
        output_holder = []

        # CREATE VARIABLE FOR LINK AND MUNICIPALITY IN CASE OF FAILURE
        link = ''
        municipality = ''
        try:

            # GET SITE CONTENT
            site = BeautifulSoup(r1.content, 'html.parser')

            # GET INFOBOX AND GET BORDER AND MARINE BODIES
            iBox = site.select_one('table.iBox')
            border = iBox.select_one('#borderType').text
            marine = iBox.select_one('#adjMarine').text
            
            # GET TABLE AND ROWS
            table = site.select_one('#lguTable')
            body = table.find('tbody').contents

            # FOR EACH ROW
            for el in body:
                #* NO MUNICIPALITIES ARE STORED FIRST
                if index <= 18:
                    # NAME OF PROVINCES WITHOUT MUNICIPALITIES
                    temp = [no_municipalities[index]]
                else:
                    # GET MUNICIPALITY BASED ON ORDER OF BARANGAY LINK MINUS THE FIRST 19 LINKS
                    temp = [output3[index - 19][1]]
                
                # FOR EACH TD
                for data in el:
                    # FIND LINK OF BARANGAY
                    name =  data.find('a')
                    if name:
                        # ADD LINK OF BARANGAY TO LIST
                        detail_links.append(name.attrs['href'])
                        # SET LINK AND MUNICIPALITY IN CASE OF FAILURE 
                        link = barangay_links[index]
                        municipality = temp[0]
                        # ADD TO TEMP HOLDER
                        temp.append(name.text)
                    else:
                        # ADD TO TEMP HOLDER
                        temp.append(data.text)
                
                # ADD TO 2D TEMPORARY HOLDER
                output_holder.append(temp)

            # COLLECT LINK OF BARANGAY DETAILS AND REQUEST ASYNC
            reqs2 = (grequests.get(base_url + link, timeout=10) for link in detail_links)
            resp2 = grequests.map(reqs2, grequests.Pool(10), size=10)

            # FOR EACH RESPONSE
            for i2, r2 in enumerate(resp2):

                # GET DETAIL SITE CONTENT
                detail_site = BeautifulSoup(r2.content, 'html.parser')

                # PRINT TEXT FOR LOGGING
                print(detail_site.find('title').text)

                # GET INFOBOX
                wrapper = detail_site.find(id='iboxWrap')
                infoTable = wrapper.find('table', class_='iBox')


                # SEARCH POSTAL CODE FROM INFOBOX
                postalCode = infoTable.find(lambda tag: tag.name == 'th' and 'Postal' in tag.text)
                # IF PRESENT, GET TEXT
                if postalCode is not None:
                    postalCode = postalCode.next_sibling.text
                
                # SEARCH COORDINATES FROM INFOBOX
                coordinates = infoTable.find(lambda tag: tag.name == 'th' and 'Coordinates' in tag.text)
                # IF PRESENT, GET TEXT AND REPLACE ESCAPE CHARS
                if coordinates is not None:
                    latitude = coordinates.next_sibling.select_one('#latitude')
                    longitude = coordinates.next_sibling.select_one('#longitude')
                    spec = longitude.next_sibling

                    location = latitude.text + ', ' + longitude.text + spec.replace("\xa0", " ")
                else:
                    # ELSE SET TO NONE
                    location = None
                
                # SEARCH ELEVATION
                elevation = infoTable.find(lambda tag: tag.name == 'th' and 'elevation' in tag.text)
                # IF PRESENT, GET TEXT AND REPLACE ESCAPE CHARS
                if elevation is not None:
                    elevation = elevation.next_sibling.text.replace("\xa0", " ")

                # EXTEND ELEMENT IN 2D TEMPORARY HOLDER BY ORDER OF DETAIL LINKS
                output_holder[i2].extend([
                    postalCode,
                    border,
                    marine,
                    location,
                    elevation
                ])

            # EXTEND OUTPUT4 WITH 2D TEMPORARY HOLDER
            output4.extend(output_holder)
            # RESET DETAIL LINKS AND 2D TEMPORARY HOLDER
            del detail_links[:], output_holder[:]

        # IF REQUEST FAILS
        except Exception as e:
            # ADD LINK AND MUNICIPALITY TO FAILED LINKS
            failed_links.append([link, municipality])
            # ADD EXCEPTION DETAILS TO LIST
            exception_details.append(e)
            # CONTINUE ITERATION
            pass

# %%
getBarangayByMunicipality()
# Out:
# Agapito del Rosario, Angeles Profile – PhilAtlas
# Amsic, Angeles Profile – PhilAtlas
# Anunas, Angeles Profile – PhilAtlas
# Balibago, Angeles Profile – PhilAtlas
# Capaya, Angeles Profile – PhilAtlas
# Claro M. Recto, Angeles Profile – PhilAtlas
# Cuayan, Angeles Profile – PhilAtlas
# Cutcut, Angeles Profile – PhilAtlas
# Cutud, Angeles Profile – PhilAtlas
# Lourdes North West, Angeles Profile – PhilAtlas
# Lourdes Sur, Angeles Profile – PhilAtlas
# Lourdes Sur East, Angeles Profile – PhilAtlas
# Malabanias, Angeles Profile – PhilAtlas
# Margot, Angeles Profile – PhilAtlas
# Mining, Angeles Profile – PhilAtlas
# Ninoy Aquino, Angeles Profile – PhilAtlas
# Pampang, Angeles Profile – PhilAtlas
# Pandan, Angeles Profile – PhilAtlas
# Pulung Cacutud, Angeles Profile – PhilAtlas
# Pulung Maragul, Angeles Profile – PhilAtlas
# Pulungbulu, Angeles Profile – PhilAtlas
# Salapungan, Angeles Profile – PhilAtlas
# San Jose, Angeles Profile – PhilAtlas
# San Nicolas, Angeles Profile – PhilAtlas
# Santa Teresita, Angeles Profile – PhilAtlas
# Santa Trinidad, Angeles Profile – PhilAtlas
# Santo Cristo, Angeles Profile – PhilAtlas
# Santo Domingo, Angeles Profile – PhilAtlas
# Santo Rosario, Angeles Profile – PhilAtlas
# Sapalibutad, Angeles Profile – PhilAtlas
# Sapangbato, Angeles Profile – PhilAtlas
# Tabun, Angeles Profile – PhilAtlas
# Virgen Delos Remedios, Angeles Profile – PhilAtlas
# Asinan, Olongapo Profile – PhilAtlas
# Banicain, Olongapo Profile – PhilAtlas
# Barreto, Olongapo Profile – PhilAtlas
# East Bajac-bajac, Olongapo Profile – PhilAtlas
# East Tapinac, Olongapo Profile – PhilAtlas
# Gordon Heights, Olongapo Profile – PhilAtlas
# Kalaklan, Olongapo Profile – PhilAtlas
# Mabayuan, Olongapo Profile – PhilAtlas
# New Cabalan, Olongapo Profile – PhilAtlas
# New Ilalim, Olongapo Profile – PhilAtlas
# New Kababae, Olongapo Profile – PhilAtlas
# New Kalalake, Olongapo Profile – PhilAtlas
# Old Cabalan, Olongapo Profile – PhilAtlas
# Pag-asa, Olongapo Profile – PhilAtlas
# Santa Rita, Olongapo Profile – PhilAtlas
# West Bajac-bajac, Olongapo Profile – PhilAtlas
# Barangay 14, Bacolod Profile – PhilAtlas
# Barangay 15, Bacolod Profile – PhilAtlas
# Barangay 16, Bacolod Profile – PhilAtlas
# Barangay 17, Bacolod Profile – PhilAtlas
# Barangay 18, Bacolod Profile – PhilAtlas
# Barangay 19, Bacolod Profile – PhilAtlas
# Barangay 2, Bacolod Profile – PhilAtlas
# Barangay 20, Bacolod Profile – PhilAtlas
# Barangay 21, Bacolod Profile – PhilAtlas
# Barangay 22, Bacolod Profile – PhilAtlas
# Barangay 23, Bacolod Profile – PhilAtlas
# Barangay 24, Bacolod Profile – PhilAtlas
# Barangay 25, Bacolod Profile – PhilAtlas
# Barangay 26, Bacolod Profile – PhilAtlas
# Barangay 27, Bacolod Profile – PhilAtlas
# Barangay 28, Bacolod Profile – PhilAtlas
# Barangay 29, Bacolod Profile – PhilAtlas
# Barangay 3, Bacolod Profile – PhilAtlas
# Barangay 30, Bacolod Profile – PhilAtlas
# Barangay 31, Bacolod Profile – PhilAtlas
# Barangay 32, Bacolod Profile – PhilAtlas
# Barangay 33, Bacolod Profile – PhilAtlas
# Barangay 34, Bacolod Profile – PhilAtlas
# Barangay 35, Bacolod Profile – PhilAtlas
# Barangay 36, Bacolod Profile – PhilAtlas
# Barangay 37, Bacolod Profile – PhilAtlas
# Barangay 38, Bacolod Profile – PhilAtlas
# Barangay 39, Bacolod Profile – PhilAtlas
# Barangay 4, Bacolod Profile – PhilAtlas
# Barangay 40, Bacolod Profile – PhilAtlas
# Barangay 41, Bacolod Profile – PhilAtlas
# Barangay 5, Bacolod Profile – PhilAtlas
# Barangay 6, Bacolod Profile – PhilAtlas
# Barangay 7, Bacolod Profile – PhilAtlas
# Barangay 8, Bacolod Profile – PhilAtlas
# Barangay 9, Bacolod Profile – PhilAtlas
# Bata, Bacolod Profile – PhilAtlas
# Cabug, Bacolod Profile – PhilAtlas
# Estefania, Bacolod Profile – PhilAtlas
# Felisa, Bacolod Profile – PhilAtlas
# Granada, Bacolod Profile – PhilAtlas
# Handumanan, Bacolod Profile – PhilAtlas
# Mandalagan, Bacolod Profile – PhilAtlas
# Mansilingan, Bacolod Profile – PhilAtlas
# Montevista, Bacolod Profile – PhilAtlas
# Pahanocoy, Bacolod Profile – PhilAtlas
# Punta Taytay, Bacolod Profile – PhilAtlas
# Singcang-Airport, Bacolod Profile – PhilAtlas
# Sum-ag, Bacolod Profile – PhilAtlas
# Taculing, Bacolod Profile – PhilAtlas
# Tangub, Bacolod Profile – PhilAtlas
# Villamonte, Bacolod Profile – PhilAtlas
# Vista Alegre, Bacolod Profile – PhilAtlas
# Abeto Mirasol Taft South, Iloilo City Profile – PhilAtlas
# Aguinaldo, Iloilo City Profile – PhilAtlas
# Airport, Iloilo City Profile – PhilAtlas
# Alalasan Lapuz, Iloilo City Profile – PhilAtlas
# Arguelles, Iloilo City Profile – PhilAtlas
# Arsenal Aduana, Iloilo City Profile – PhilAtlas
# Bakhaw, Iloilo City Profile – PhilAtlas
# Balabago, Iloilo City Profile – PhilAtlas
# Balantang, Iloilo City Profile – PhilAtlas
# Suba Poblacion, Cebu City Profile – PhilAtlas
# Sudlon I, Cebu City Profile – PhilAtlas
# Sudlon II, Cebu City Profile – PhilAtlas
# T. Padilla, Cebu City Profile – PhilAtlas
# Tabunan, Cebu City Profile – PhilAtlas
# Tagbao, Cebu City Profile – PhilAtlas
# Talamban, Cebu City Profile – PhilAtlas
# Taptap, Cebu City Profile – PhilAtlas
# Tejero, Cebu City Profile – PhilAtlas
# Tinago, Cebu City Profile – PhilAtlas
# Tisa, Cebu City Profile – PhilAtlas
# To-ong Pardo, Cebu City Profile – PhilAtlas
# Zapatera, Cebu City Profile – PhilAtlas
# Agus, Lapu-Lapu Profile – PhilAtlas
# Babag, Lapu-Lapu Profile – PhilAtlas
# Bankal, Lapu-Lapu Profile – PhilAtlas
# Baring, Lapu-Lapu Profile – PhilAtlas
# Basak, Lapu-Lapu Profile – PhilAtlas
# Buaya, Lapu-Lapu Profile – PhilAtlas
# Calawisan, Lapu-Lapu Profile – PhilAtlas
# Canjulao, Lapu-Lapu Profile – PhilAtlas
# Caubian, Lapu-Lapu Profile – PhilAtlas
# Cawhagan, Lapu-Lapu Profile – PhilAtlas
# Caw-oy, Lapu-Lapu Profile – PhilAtlas
# Gun-ob, Lapu-Lapu Profile – PhilAtlas
# Ibo, Lapu-Lapu Profile – PhilAtlas
# Looc, Lapu-Lapu Profile – PhilAtlas
# Mactan, Lapu-Lapu Profile – PhilAtlas
# Maribago, Lapu-Lapu Profile – PhilAtlas
# Marigondon, Lapu-Lapu Profile – PhilAtlas
# Pajac, Lapu-Lapu Profile – PhilAtlas
# Pajo, Lapu-Lapu Profile – PhilAtlas
# Pangan-an, Lapu-Lapu Profile – PhilAtlas
# Poblacion, Lapu-Lapu Profile – PhilAtlas
# Punta Engaño, Lapu-Lapu Profile – PhilAtlas
# Pusok, Lapu-Lapu Profile – PhilAtlas
# Sabang, Lapu-Lapu Profile – PhilAtlas
# San Vicente, Lapu-Lapu Profile – PhilAtlas
# Santa Rosa, Lapu-Lapu Profile – PhilAtlas
# Subabasbas, Lapu-Lapu Profile – PhilAtlas
# Talima, Lapu-Lapu Profile – PhilAtlas
# Tingo, Lapu-Lapu Profile – PhilAtlas
# Tungasan, Lapu-Lapu Profile – PhilAtlas
# Alang-alang, Mandaue Profile – PhilAtlas
# Bakilid, Mandaue Profile – PhilAtlas
# Banilad, Mandaue Profile – PhilAtlas
# Basak, Mandaue Profile – PhilAtlas
# Cabancalan, Mandaue Profile – PhilAtlas
# Cambaro, Mandaue Profile – PhilAtlas
# Canduman, Mandaue Profile – PhilAtlas
# Casili, Mandaue Profile – PhilAtlas
# Casuntingan, Mandaue Profile – PhilAtlas
# Centro, Mandaue Profile – PhilAtlas
# Cubacub, Mandaue Profile – PhilAtlas
# Guizo, Mandaue Profile – PhilAtlas
# Ibabao-Estancia, Mandaue Profile – PhilAtlas
# Jagobiao, Mandaue Profile – PhilAtlas
# Labogon, Mandaue Profile – PhilAtlas
# Looc, Mandaue Profile – PhilAtlas
# Maguikay, Mandaue Profile – PhilAtlas
# Mantuyong, Mandaue Profile – PhilAtlas
# Barangay 83-B, Tacloban Profile – PhilAtlas
# Barangay 83-C, Tacloban Profile – PhilAtlas
# Barangay 84, Tacloban Profile – PhilAtlas
# Barangay 85, Tacloban Profile – PhilAtlas
# Barangay 86, Tacloban Profile – PhilAtlas
# Barangay 87, Tacloban Profile – PhilAtlas
# Barangay 88, Tacloban Profile – PhilAtlas
# Barangay 89, Tacloban Profile – PhilAtlas
# Barangay 8-A, Tacloban Profile – PhilAtlas
# Barangay 90, Tacloban Profile – PhilAtlas
# Barangay 91, Tacloban Profile – PhilAtlas
# Barangay 92, Tacloban Profile – PhilAtlas
# Barangay 93, Tacloban Profile – PhilAtlas
# Barangay 94, Tacloban Profile – PhilAtlas
# Barangay 94-A, Tacloban Profile – PhilAtlas
# Barangay 95, Tacloban Profile – PhilAtlas
# Barangay 95-A, Tacloban Profile – PhilAtlas
# Barangay 96, Tacloban Profile – PhilAtlas
# Barangay 97, Tacloban Profile – PhilAtlas
# Barangay 98, Tacloban Profile – PhilAtlas
# Barangay 99, Tacloban Profile – PhilAtlas
# El Reposo, Tacloban Profile – PhilAtlas
# Libertad, Tacloban Profile – PhilAtlas
# Nula-tula, Tacloban Profile – PhilAtlas
# Aguada, Isabela City, Basilan Profile – PhilAtlas
# Balatanay, Isabela City, Basilan Profile – PhilAtlas
# Baluno, Isabela City, Basilan Profile – PhilAtlas
# Begang, Isabela City, Basilan Profile – PhilAtlas
# Binuangan, Isabela City, Basilan Profile – PhilAtlas
# Busay, Isabela City, Basilan Profile – PhilAtlas
# Cabunbata, Isabela City, Basilan Profile – PhilAtlas
# Calvario, Isabela City, Basilan Profile – PhilAtlas
# Carbon, Isabela City, Basilan Profile – PhilAtlas
# Diki, Isabela City, Basilan Profile – PhilAtlas
# Doña Ramona T. Alano, Isabela City, Basilan Profile – PhilAtlas
# Isabela Eastside, Isabela City, Basilan Profile – PhilAtlas
# Isabela Proper, Isabela City, Basilan Profile – PhilAtlas
# Kapatagan Grande, Isabela City, Basilan Profile – PhilAtlas
# Kapayawan, Isabela City, Basilan Profile – PhilAtlas
# Kaumpurnah Zone I, Isabela City, Basilan Profile – PhilAtlas
# Kaumpurnah Zone II, Isabela City, Basilan Profile – PhilAtlas
# Kaumpurnah Zone III, Isabela City, Basilan Profile – PhilAtlas
# Kumalarang, Isabela City, Basilan Profile – PhilAtlas
# La Piedad, Isabela City, Basilan Profile – PhilAtlas
# Lampinigan, Isabela City, Basilan Profile – PhilAtlas
# Lanote, Isabela City, Basilan Profile – PhilAtlas
# Lukbuton, Isabela City, Basilan Profile – PhilAtlas
# Lumbang, Isabela City, Basilan Profile – PhilAtlas
# Makiri, Isabela City, Basilan Profile – PhilAtlas
# Maligue, Isabela City, Basilan Profile – PhilAtlas
# Marang-marang, Isabela City, Basilan Profile – PhilAtlas
# Marketsite, Isabela City, Basilan Profile – PhilAtlas
# Masula, Isabela City, Basilan Profile – PhilAtlas
# Menzi, Isabela City, Basilan Profile – PhilAtlas
# Panigayan, Isabela City, Basilan Profile – PhilAtlas
# Panunsulan, Isabela City, Basilan Profile – PhilAtlas
# Upper Hinaplanon, Iligan Profile – PhilAtlas
# Villa Verde, Iligan Profile – PhilAtlas
# Acacia, Davao City Profile – PhilAtlas
# Agdao, Davao City Profile – PhilAtlas
# Alambre, Davao City Profile – PhilAtlas
# Alejandra Navarro, Davao City Profile – PhilAtlas
# Alfonso Angliongto Sr., Davao City Profile – PhilAtlas
# Angalan, Davao City Profile – PhilAtlas
# Atan-awe, Davao City Profile – PhilAtlas
# Baganihan, Davao City Profile – PhilAtlas
# Bago Aplaya, Davao City Profile – PhilAtlas
# Bago Gallera, Davao City Profile – PhilAtlas
# Bago Oshiro, Davao City Profile – PhilAtlas
# Baguio, Davao City Profile – PhilAtlas
# Balengaeng, Davao City Profile – PhilAtlas
# Baliok, Davao City Profile – PhilAtlas
# Bangkas Heights, Davao City Profile – PhilAtlas
# Bantol, Davao City Profile – PhilAtlas
# Baracatan, Davao City Profile – PhilAtlas
# Barangay 10-A, Davao City Profile – PhilAtlas
# Barangay 11-B, Davao City Profile – PhilAtlas
# Barangay 12-B, Davao City Profile – PhilAtlas
# Barangay 13-B, Davao City Profile – PhilAtlas
# Barangay 14-B, Davao City Profile – PhilAtlas
# Barangay 15-B, Davao City Profile – PhilAtlas
# Barangay 16-B, Davao City Profile – PhilAtlas
# Barangay 17-B, Davao City Profile – PhilAtlas
# Barangay 18-B, Davao City Profile – PhilAtlas
# Barangay 19-B, Davao City Profile – PhilAtlas
# Barangay 1-A, Davao City Profile – PhilAtlas
# Barangay 20-B, Davao City Profile – PhilAtlas
# Barangay 21-C, Davao City Profile – PhilAtlas
# Barangay 22-C, Davao City Profile – PhilAtlas
# Barangay 23-C, Davao City Profile – PhilAtlas
# Barangay 24-C, Davao City Profile – PhilAtlas
# Barangay 25-C, Davao City Profile – PhilAtlas
# Barangay 26-C, Davao City Profile – PhilAtlas
# ...
# Tanum, Patikul, Sulu Profile – PhilAtlas
# Taung, Patikul, Sulu Profile – PhilAtlas
# Timpok, Patikul, Sulu Profile – PhilAtlas
# Tugas, Patikul, Sulu Profile – PhilAtlas
# Umangay, Patikul, Sulu Profile – PhilAtlas
# Bakud, Siasi, Sulu Profile – PhilAtlas
# Buan, Siasi, Sulu Profile – PhilAtlas
# Bulansing Tara, Siasi, Sulu Profile – PhilAtlas
# Bulihkullul, Siasi, Sulu Profile – PhilAtlas
# Campo Islam, Siasi, Sulu Profile – PhilAtlas
# Duggo, Siasi, Sulu Profile – PhilAtlas
# Duhol Tara, Siasi, Sulu Profile – PhilAtlas
# East Kungtad, Siasi, Sulu Profile – PhilAtlas
# East Sisangat, Siasi, Sulu Profile – PhilAtlas
# Ipil, Siasi, Sulu Profile – PhilAtlas
# Jambangan, Siasi, Sulu Profile – PhilAtlas
# Kabubu, Siasi, Sulu Profile – PhilAtlas
# Kong-Kong Laminusa, Siasi, Sulu Profile – PhilAtlas
# Kud-kud, Siasi, Sulu Profile – PhilAtlas
# Kungtad West, Siasi, Sulu Profile – PhilAtlas
# Latung, Siasi, Sulu Profile – PhilAtlas
# Luuk Laminusa, Siasi, Sulu Profile – PhilAtlas
# Luuk Tara, Siasi, Sulu Profile – PhilAtlas
# Manta, Siasi, Sulu Profile – PhilAtlas
# Minapan, Siasi, Sulu Profile – PhilAtlas
# Nipa-nipa, Siasi, Sulu Profile – PhilAtlas
# North Laud, Siasi, Sulu Profile – PhilAtlas
# North Manta, Siasi, Sulu Profile – PhilAtlas
# North Musu Laud, Siasi, Sulu Profile – PhilAtlas
# North Silumpak, Siasi, Sulu Profile – PhilAtlas
# Pislong, Siasi, Sulu Profile – PhilAtlas
# Poblacion, Siasi, Sulu Profile – PhilAtlas
# Punungan, Siasi, Sulu Profile – PhilAtlas
# Puukan Laminusa, Siasi, Sulu Profile – PhilAtlas
# Ratag, Siasi, Sulu Profile – PhilAtlas
# Sablay, Siasi, Sulu Profile – PhilAtlas
# Sarukot, Siasi, Sulu Profile – PhilAtlas
# Siburi, Siasi, Sulu Profile – PhilAtlas
# Singko, Siasi, Sulu Profile – PhilAtlas
# Siolakan, Siasi, Sulu Profile – PhilAtlas
# Siowing, Siasi, Sulu Profile – PhilAtlas
# Sipanding, Siasi, Sulu Profile – PhilAtlas
# Sisangat, Siasi, Sulu Profile – PhilAtlas
# Siundoh, Siasi, Sulu Profile – PhilAtlas
# South Musu Laud, Siasi, Sulu Profile – PhilAtlas
# South Silumpak, Siasi, Sulu Profile – PhilAtlas
# Southwestern Bulikullul, Siasi, Sulu Profile – PhilAtlas
# Subah Buaya, Siasi, Sulu Profile – PhilAtlas
# Tampakan Laminusa, Siasi, Sulu Profile – PhilAtlas
# Tengah Laminusa, Siasi, Sulu Profile – PhilAtlas
# Tong Laminusa, Siasi, Sulu Profile – PhilAtlas
# Tonglabah, Siasi, Sulu Profile – PhilAtlas
# Tong-tong, Siasi, Sulu Profile – PhilAtlas
# Tubig Kutah, Siasi, Sulu Profile – PhilAtlas
# Tulling, Siasi, Sulu Profile – PhilAtlas
# Andalan, Talipao, Sulu Profile – PhilAtlas
# Bagsak, Talipao, Sulu Profile – PhilAtlas
# Bandang, Talipao, Sulu Profile – PhilAtlas
# Bilaan, Talipao, Sulu Profile – PhilAtlas
# Bud Bunga, Talipao, Sulu Profile – PhilAtlas
# Buntod, Talipao, Sulu Profile – PhilAtlas
# Buroh, Talipao, Sulu Profile – PhilAtlas
# Dalih, Talipao, Sulu Profile – PhilAtlas
# Gata, Talipao, Sulu Profile – PhilAtlas
# Kabatuhan Bilaan, Talipao, Sulu Profile – PhilAtlas
# Kabatuhan Tiis, Talipao, Sulu Profile – PhilAtlas
# Kabungkol, Talipao, Sulu Profile – PhilAtlas
# Kagay, Talipao, Sulu Profile – PhilAtlas
# Kahawa, Talipao, Sulu Profile – PhilAtlas
# Kandaga, Talipao, Sulu Profile – PhilAtlas
# Kanlibot, Talipao, Sulu Profile – PhilAtlas
# Kiutaan, Talipao, Sulu Profile – PhilAtlas
# Kuhaw, Talipao, Sulu Profile – PhilAtlas
# Kulamboh, Talipao, Sulu Profile – PhilAtlas
# Kuttong, Talipao, Sulu Profile – PhilAtlas
# Lagtoh, Talipao, Sulu Profile – PhilAtlas
# Lambanah, Talipao, Sulu Profile – PhilAtlas
# Liban, Talipao, Sulu Profile – PhilAtlas
# Liu-Bud Pantao, Talipao, Sulu Profile – PhilAtlas
# Lower Binuang, Talipao, Sulu Profile – PhilAtlas
# Lower Kamuntayan, Talipao, Sulu Profile – PhilAtlas
# Lower Laus, Talipao, Sulu Profile – PhilAtlas
# Lower Sinumaan, Talipao, Sulu Profile – PhilAtlas
# Lower Talipao, Talipao, Sulu Profile – PhilAtlas
# Lumbayao, Talipao, Sulu Profile – PhilAtlas
# Lumping Pigih Daho, Talipao, Sulu Profile – PhilAtlas
# Lungkiaban, Talipao, Sulu Profile – PhilAtlas
# Mabahay, Talipao, Sulu Profile – PhilAtlas
# Mahala, Talipao, Sulu Profile – PhilAtlas
# Mampallam, Talipao, Sulu Profile – PhilAtlas
# Marsada, Talipao, Sulu Profile – PhilAtlas
# Mauboh, Talipao, Sulu Profile – PhilAtlas
# Mungit-mungit, Talipao, Sulu Profile – PhilAtlas
# Niog-Sangahan, Talipao, Sulu Profile – PhilAtlas
# Pantao, Talipao, Sulu Profile – PhilAtlas
# Samak, Talipao, Sulu Profile – PhilAtlas
# Talipao Proper, Talipao, Sulu Profile – PhilAtlas
# Tampakan, Talipao, Sulu Profile – PhilAtlas
# Tiis, Talipao, Sulu Profile – PhilAtlas
# Tinggah, Talipao, Sulu Profile – PhilAtlas
# Tubod, Talipao, Sulu Profile – PhilAtlas
# Tuyang, Talipao, Sulu Profile – PhilAtlas
# Upper Binuang, Talipao, Sulu Profile – PhilAtlas
# Upper Kamuntayan, Talipao, Sulu Profile – PhilAtlas
# Upper Laus, Talipao, Sulu Profile – PhilAtlas
# Upper Sinumaan, Talipao, Sulu Profile – PhilAtlas
# Upper Talipao, Talipao, Sulu Profile – PhilAtlas
# Alu-Kabingaan, Tapul, Sulu Profile – PhilAtlas
# Banting, Tapul, Sulu Profile – PhilAtlas
# Hawan, Tapul, Sulu Profile – PhilAtlas
# Kalang, Tapul, Sulu Profile – PhilAtlas
# Kamaunggi, Tapul, Sulu Profile – PhilAtlas
# Kanaway, Tapul, Sulu Profile – PhilAtlas
# Kanmangon, Tapul, Sulu Profile – PhilAtlas
# Kaumpang, Tapul, Sulu Profile – PhilAtlas
# Pagatpat, Tapul, Sulu Profile – PhilAtlas
# Pangdan, Tapul, Sulu Profile – PhilAtlas
# Puok, Tapul, Sulu Profile – PhilAtlas
# Sayli, Tapul, Sulu Profile – PhilAtlas
# Sumambat, Tapul, Sulu Profile – PhilAtlas
# Tangkapaan, Tapul, Sulu Profile – PhilAtlas
# Tulakan, Tapul, Sulu Profile – PhilAtlas
# Bongao Poblacion, Bongao, Tawi-Tawi Profile – PhilAtlas
# Ipil, Bongao, Tawi-Tawi Profile – PhilAtlas
# Kamagong, Bongao, Tawi-Tawi Profile – PhilAtlas
# Karungdong, Bongao, Tawi-Tawi Profile – PhilAtlas
# Lagasan, Bongao, Tawi-Tawi Profile – PhilAtlas
# Lakit Lakit, Bongao, Tawi-Tawi Profile – PhilAtlas
# Lamion, Bongao, Tawi-Tawi Profile – PhilAtlas
South Ubian, Tawi-Tawi Profile – PhilAtlas
# Tangngah, South Ubian, Tawi-Tawi Profile – PhilAtlas
# Tinda-tindahan, South Ubian, Tawi-Tawi Profile – PhilAtlas
# Tong Tampakan, South Ubian, Tawi-Tawi Profile – PhilAtlas
# Tubig Dayang, South Ubian, Tawi-Tawi Profile – PhilAtlas
# Tubig Dayang Center, South Ubian, Tawi-Tawi Profile – PhilAtlas
# Tubig Dayang Riverside, South Ubian, Tawi-Tawi Profile – PhilAtlas
# Tukkai, South Ubian, Tawi-Tawi Profile – PhilAtlas
# Unas-unas, South Ubian, Tawi-Tawi Profile – PhilAtlas
# Baliungan, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Ballak, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Butun, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Himbah, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Kakoong, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Kalang-kalang, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Kepeng, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Lahay-lahay, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Naungan, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Salamat, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Sallangan, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Sapa, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Sibakloon, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Silantup, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Tandubato, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Tangngah, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Tapian, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Tapian Sukah, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Taruk, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Tongbangkaw, Tandubas, Tawi-Tawi Profile – PhilAtlas
# Likud Bakkao, Turtle Islands, Tawi-Tawi Profile – PhilAtlas
# Taganak Poblacion, Turtle Islands, Tawi-Tawi Profile – PhilAtlas

# %%
# SEE FAILED LINKS AND DETAILS
failed_links, exception_details
# Out:
# ([], [])

# %%
# REPEAT PROCESS FROM getBarangayByMunicipality
def retryFailedLinks():
    # COLLECT FAILED REQUESTS AND RETRY ASYNC
    req1 = (grequests.get(base_url + e[0]) for e in failed_links)
    resp1 = grequests.map(req1, grequests.Pool(10), size=5)

    output_holder = []
    detail_links = []

    for i1, r1 in enumerate(resp1):
        try:
            site = BeautifulSoup(r1.content, 'html.parser')
            iBox = site.select_one('table.iBox')
            border = iBox.select_one('#borderType').text
            marine = iBox.select_one('#adjMarine').text
            

            table = site.select_one('#lguTable')
            body = table.find('tbody').contents

            for el in body:
                # USE MUNICIPALITY IN FAILED LINKS
                temp = [failed_links[i1][1]]
                
                for data in el:
                    name =  data.find('a')
                    if name:
                        detail_links.append(name.attrs['href'])
                        temp.append(name.text)
                    else:  
                        temp.append(data.text)
                output_holder.append(temp)

                
            reqs2 = (grequests.get(base_url + link, timeout=10) for link in detail_links)
            resp2 = grequests.map(reqs2, grequests.Pool(10), size=10)
            for i2, r2 in enumerate(resp2):
                detail_site = BeautifulSoup(r2.content, 'html.parser')
                print(detail_site.find('title').text)

                wrapper = detail_site.find(id='iboxWrap')
                infoTable = wrapper.find('table', class_='iBox')

                postalCode = infoTable.find(lambda tag: tag.name == 'th' and 'Postal' in tag.text)
                if postalCode is not None:
                    postalCode = postalCode.next_sibling.text
                

                coordinates = infoTable.find(lambda tag: tag.name == 'th' and 'Coordinates' in tag.text)
                if coordinates is not None:
                    latitude = coordinates.next_sibling.select_one('#latitude')
                    longitude = coordinates.next_sibling.select_one('#longitude')
                    spec = longitude.next_sibling

                    location = latitude.text + ', ' + longitude.text + spec.replace("\xa0", " ")
                else:
                    location = None
                

                elevation = infoTable.find(lambda tag: tag.name == 'th' and 'elevation' in tag.text)
                if elevation is not None:
                    elevation = elevation.next_sibling.text.replace("\xa0", " ")


                output_holder[i2].extend([
                    postalCode,
                    border,
                    marine,
                    location,
                    elevation
                ])

            output4.extend(output_holder)
            del detail_links[:], output_holder[:]
        except Exception:
            print(r1)

# %%
retryFailedLinks()

# %%
# MAKE OUTPUT4 DATAFRAME
df = pd.DataFrame(output4, columns=headers4)
# ISABELA CITY IS DUPLICATED IN BASILAN AND REGION 9
df.drop_duplicates(inplace=True)
# EXPORT TO CSV
df.to_csv('../output/output_4.csv', index=False)
